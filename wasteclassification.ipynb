# %% [markdown]
# ## Waste Management using CNN Model

# %%
pip install opencv-python
# Out:
# Note: you may need to restart the kernel to use updated packages.Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/60.8 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/60.8 kB ? eta -:--:--
#      ------------------------------- ------ 51.2/60.8 kB 871.5 kB/s eta 0:00:01
#      -------------------------------------- 60.8/60.8 kB 816.2 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/39.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/39.5 MB 1.3 MB/s eta 0:00:31
#    ---------------------------------------- 0.1/39.5 MB 812.7 kB/s eta 0:00:49
#    ---------------------------------------- 0.1/39.5 MB 744.7 kB/s eta 0:00:53
#    ---------------------------------------- 0.1/39.5 MB 798.9 kB/s eta 0:00:50
#    ---------------------------------------- 0.2/39.5 MB 817.0 kB/s eta 0:00:49
# ...

# %%
# importing necessary libraries
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
import warnings
warnings.filterwarnings()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[1], line 3
#       1 # importing necessary libraries
#       2 import numpy as np
# ----> 3 import pandas as pd
#       4 import matplotlib.pyplot as plt
#       5 import cv2
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install tensorflow
# Out:
# Defaulting to user installation because normal site-packages is not writeableNote: you may need to restart the kernel to use updated packages.
#
# ...
#      ---------------------------------------- 0.0/59.7 kB ? eta -:--:--
#      ------ --------------------------------- 10.2/59.7 kB ? eta -:--:--
#      -------------------------------- ----- 51.2/59.7 kB 660.6 kB/s eta 0:00:01
#      -------------------------------------- 59.7/59.7 kB 634.6 kB/s eta 0:00:00
# ...
#      ---------------------------------------- 0.0/48.6 kB ? eta -:--:--
#      -------- ------------------------------- 10.2/48.6 kB ? eta -:--:--
#      -------------------------------- ----- 41.0/48.6 kB 653.6 kB/s eta 0:00:01
#      -------------------------------------- 48.6/48.6 kB 618.4 kB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
#    ---------------------------------------- 0.0/390.3 MB ? eta -:--:--
# ...

# %%
# importing necessary libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
pip install pandas
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.0/11.5 MB ? eta -:--:--
#    ---------------------------------------- 0.1/11.5 MB 919.0 kB/s eta 0:00:13
#    ---------------------------------------- 0.1/11.5 MB 1.1 MB/s eta 0:00:11
#     --------------------------------------- 0.2/11.5 MB 1.2 MB/s eta 0:00:10
#    - -------------------------------------- 0.3/11.5 MB 1.4 MB/s eta 0:00:08
#    - -------------------------------------- 0.4/11.5 MB 1.6 MB/s eta 0:00:07
#    - -------------------------------------- 0.6/11.5 MB 1.8 MB/s eta 0:00:07
#    -- ------------------------------------- 0.7/11.5 MB 1.9 MB/s eta 0:00:06
#    -- ------------------------------------- 0.8/11.5 MB 1.9 MB/s eta 0:00:06
# ...

# %%
# importing necessary libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 4
#       2 import numpy as np
#       3 import pandas as pd
# ----> 4 import matplotlib.pyplot as plt
#       5 import cv2
#       6 from tqdm import tqdm
#
# ModuleNotFoundError: No module named 'matplotlib'

# %%
pip install matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
#      ---------------------------------------- 0.0/169.1 kB ? eta -:--:--
#      ------- ------------------------------- 30.7/169.1 kB 1.3 MB/s eta 0:00:01
#      -------------------------------- ----- 143.4/169.1 kB 2.1 MB/s eta 0:00:01
#      -------------------------------------- 169.1/169.1 kB 2.0 MB/s eta 0:00:00
# ...
#    ---------------------------------------- 0.0/8.0 MB ? eta -:--:--
#     --------------------------------------- 0.2/8.0 MB 3.3 MB/s eta 0:00:03
#    - -------------------------------------- 0.3/8.0 MB 3.4 MB/s eta 0:00:03
#    -- ------------------------------------- 0.4/8.0 MB 3.4 MB/s eta 0:00:03
#    --- ------------------------------------ 0.6/8.0 MB 3.2 MB/s eta 0:00:03
#    --- ------------------------------------ 0.7/8.0 MB 3.1 MB/s eta 0:00:03
#    ---- ----------------------------------- 0.9/8.0 MB 3.3 MB/s eta 0:00:03
# ...

# %%
# importing necessary libraries 
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import cv2
from tqdm import tqdm
import warnings
warnings.filterwarnings('ignore')

# %%
train_path = "DATASET1/TRAIN"
test_path = "DATASET1/TEST"

# %%
# Importing Libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.utils import plot_model
from glob import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[10], line 2
#       1 # Importing Libraries
# ----> 2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalalization
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\__init__.py:30
#      15 """
#      16 Top-level module of TensorFlow. By convention, we refer to this module as
#      17 `tf` instead of `tensorflow`, following the common practice of importing
#    (...)
#      26 this file with a file generated from [`api_template.__init__.py`](https://www.github.com/tensorflow/tensorflow/blob/master/tensorflow/api_template.__init__.py)
#      27 """
# ...

# %%
# Importing Libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.utils import plot_model
from glob import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Importing Libraries
# ----> 2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalization
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\__init__.py:30
#      15 """
#      16 Top-level module of TensorFlow. By convention, we refer to this module as
#      17 `tf` instead of `tensorflow`, following the common practice of importing
#    (...)
#      26 this file with a file generated from [`api_template.__init__.py`](https://www.github.com/tensorflow/tensorflow/blob/master/tensorflow/api_template.__init__.py)
#      27 """
# ...

# %%
# Importing Libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.utils import plot_model
from glob import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[13], line 2
#       1 # Importing Libraries
# ----> 2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalization
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\__init__.py:30
#      15 """
#      16 Top-level module of TensorFlow. By convention, we refer to this module as
#      17 `tf` instead of `tensorflow`, following the common practice of importing
#    (...)
#      26 this file with a file generated from [`api_template.__init__.py`](https://www.github.com/tensorflow/tensorflow/blob/master/tensorflow/api_template.__init__.py)
#      27 """
# ...

# %%
python3 --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[15], line 1
# ----> 1 python3 --version
#
# NameError: name 'python3' is not defined

# %%
pyenv install --patch <python-version>
# Out:
#   Cell In[14], line 1
#     pyenv install --patch <python-version>
#           ^
# SyntaxError: invalid syntax

# %%
python3 -m ensurepip --upgrade
# Out:
#   Cell In[16], line 1
#     python3 -m ensurepip --upgrade
#                ^
# SyntaxError: invalid syntax

# %%
.\myenv\Scripts\Activate
# Out:
#   Cell In[17], line 1
#     .\myenv\Scripts\Activate
#     ^
# SyntaxError: invalid syntax

# %%
pip install tensorflow matplotlib
# Out:
# Defaulting to user installation because normal site-packages is not writeable
# ...
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.0 -> 24.3.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
deactivate
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[19], line 1
# ----> 1 deactivate
#
# NameError: name 'deactivate' is not defined

# %%
# Importing Libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.utils import plot_model
from glob import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[20], line 2
#       1 # Importing Libraries
# ----> 2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalization
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\__init__.py:30
#      15 """
#      16 Top-level module of TensorFlow. By convention, we refer to this module as
#      17 `tf` instead of `tensorflow`, following the common practice of importing
#    (...)
#      26 this file with a file generated from [`api_template.__init__.py`](https://www.github.com/tensorflow/tensorflow/blob/master/tensorflow/api_template.__init__.py)
#      27 """
# ...

# %%
# Importing Libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.utils import plot_model
from glob import glob
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[21], line 2
#       1 # Importing Libraries
# ----> 2 from tensorflow.keras.models import Sequential
#       3 from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalization
#       4 from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
#
# File ~\AppData\Roaming\Python\Python312\site-packages\tensorflow\__init__.py:30
#      15 """
#      16 Top-level module of TensorFlow. By convention, we refer to this module as
#      17 `tf` instead of `tensorflow`, following the common practice of importing
#    (...)
#      26 this file with a file generated from [`api_template.__init__.py`](https://www.github.com/tensorflow/tensorflow/blob/master/tensorflow/api_template.__init__.py)
#      27 """
# ...

# %%
python --version
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[22], line 1
# ----> 1 python --version
#
# NameError: name 'python' is not defined

# %%
# Importing Libraries
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Activation, Dropout, Flatten, Dense, BatchNormalization
from tensorflow.keras.preprocessing.image import ImageDataGenerator, img_to_array, load_img
from tensorflow.keras.utils import plot_model
from glob import glob

# %%
# Visualization
from cv2 import cvtColor
x_data = []
y_data = []
for category in glob(train_path+'/*'):
    for file in tqdm(glob(category+'/*')):
        img_array = cv2.imread(file)
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        x_data.append(img_array)
        y_data.append(category.split('/')[-1])
data = pd.DataFrame({'image':x_data, 'label':y_data})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 5
#       3 x_data = []
#       4 y_data = []
# ----> 5 for category in glob(train_path+'/*'):
#       6     for file in tqdm(glob(category+'/*')):
#       7         img_array = cv2.imread(file)
#
# NameError: name 'train_path' is not defined

# %%
# Define the path to training data
train_path = "DATASET1/TRAIN"

# Visualization
from cv2 import cvtColor
import cv2
import glob
from tqdm import tqdm
import pandas as pd

x_data = []
y_data = []
for category in glob.glob(train_path + '/*'):  # Use glob.glob()
    for file in tqdm(glob.glob(category + '/*')):
        img_array = cv2.imread(file)
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        x_data.append(img_array)
        y_data.append(category.split('/')[-1])

data = pd.DataFrame({'image': x_data, 'label': y_data})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[3], line 8
#       6 import cv2
#       7 import glob
# ----> 8 from tqdm import tqdm
#       9 import pandas as pd
#      11 x_data = []
#
# ModuleNotFoundError: No module named 'tqdm'

# %%
pip install tqdm
# Out:
# ...
#
# ...
#   WARNING: The script tqdm.exe is installed in 'c:\Users\USER\AppData\Local\Programs\Python\Python310\Scripts' which is not on PATH.
#   Consider adding this directory to PATH or, if you prefer to suppress this warning, use --no-warn-script-location.
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\USER\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# Define the path to training data
train_path = "DATASET1/TRAIN"

# Visualization
from cv2 import cvtColor
import cv2
import glob
from tqdm import tqdm
import pandas as pd

x_data = []
y_data = []
for category in glob.glob(train_path + '/*'):  # Use glob.glob()
    for file in tqdm(glob.glob(category + '/*')):
        img_array = cv2.imread(file)
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        x_data.append(img_array)
        y_data.append(category.split('/')[-1])

data = pd.DataFrame({'image': x_data, 'label': y_data})
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[5], line 9
#       7 import glob
#       8 from tqdm import tqdm
# ----> 9 import pandas as pd
#      11 x_data = []
#      12 y_data = []
#
# ModuleNotFoundError: No module named 'pandas'

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\USER\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# Define the path to training data
train_path = "DATASET1/TRAIN"

# Visualization
from cv2 import cvtColor
import cv2
import glob
from tqdm import tqdm
import pandas as pd

x_data = []
y_data = []
for category in glob.glob(train_path + '/*'):  # Use glob.glob()
    for file in tqdm(glob.glob(category + '/*')):
        img_array = cv2.imread(file)
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        x_data.append(img_array)
        y_data.append(category.split('/')[-1])

data = pd.DataFrame({'image': x_data, 'label': y_data})
# Out:
# ...
#  82%|████████▏ | 8236/9999 [01:51<00:22, 77.77it/s]
# The Kernel crashed while executing code in the current cell or a previous cell.
#
# Please review the code in the cell(s) to identify a possible cause of the failure.
#
# Click <a href='https://aka.ms/vscodeJupyterKernelCrash'>here</a> for more info.
#
# View Jupyter <a href='command:jupyter.viewOutput'>log</a> for further details.

# %%
# Define the path to training data
train_path = "DATASET1/TRAIN"

# Visualization
from cv2 import cvtColor
import cv2
import glob
from tqdm import tqdm
import pandas as pd

x_data = []
y_data = []
for category in glob.glob(train_path + '/*'):
    for i, file in enumerate(tqdm(glob.glob(category + '/*'))):
        if i >= 10:  # Limit to 10 images per category for testing
            break
        img_array = cv2.imread(file)
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        x_data.append(img_array)
        y_data.append(category.split('/')[-1])

data = pd.DataFrame({'image': x_data, 'label': y_data})
# Out:
# ...
#   0%|          | 10/9999 [00:00<00:10, 994.08it/s]

# %%
data.shape
# Out:
# (20, 2)

# %%
# Define the path to training data
train_path = "DATASET1/TRAIN"

# Visualization
from cv2 import cvtColor
import cv2
import glob
from tqdm import tqdm
import pandas as pd

x_data = []
y_data = []
for category in glob.glob(train_path + '/*'):
    for i, file in enumerate(tqdm(glob.glob(category + '/*'))):
        if i >= 10:  # Limit to 10 images per category for testing
            break
        img_array = cv2.imread(file)
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        x_data.append(img_array)
        y_data.append(category.split('/')[-1])

data = pd.DataFrame({'image': x_data, 'label': y_data})
# Out:
# ...
#   0%|          | 10/9999 [00:00<00:10, 953.45it/s]

# %%
data.shape
# Out:
# (20, 2)

# %%
img_array = cv2.resize(img_array, (128, 128))  # Resize to 128x128 pixels

# %%
pip install --upgrade opencv-python tqdm pandas
# Out:
# ...
#   Attempting uninstall: opencv-python
#     Found existing installation: opencv-python 4.10.0.84
#     Uninstalling opencv-python-4.10.0.84:
#       Successfully uninstalled opencv-python-4.10.0.84
# Note: you may need to restart the kernel to use updated packages.
# ERROR: Could not install packages due to an OSError: [WinError 5] Access is denied: 'C:\\Users\\USER\\AppData\\Local\\Programs\\Python\\Python310\\Lib\\site-packages\\~v2\\cv2.pyd'
# Consider using the `--user` option or check the permissions.
#
# WARNING: You are using pip version 21.2.3; however, version 24.3.1 is available.
# You should consider upgrading via the 'c:\Users\USER\AppData\Local\Programs\Python\Python310\python.exe -m pip install --upgrade pip' command.

# %%
# Define the path to training data
train_path = "DATASET1/TRAIN"

# Visualization
from cv2 import cvtColor
import cv2
import glob
from tqdm import tqdm
import pandas as pd

x_data = []
y_data = []
for category in glob.glob(train_path + '/*'):
    for i, file in enumerate(tqdm(glob.glob(category + '/*'))):
        if i >= 10:  # Limit to 10 images per category for testing
            break
        img_array = cv2.imread(file)
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        x_data.append(img_array)
        y_data.append(category.split('/')[-1])

data = pd.DataFrame({'image': x_data, 'label': y_data})
# Out:
# ...
#   0%|          | 10/9999 [00:00<00:13, 716.01it/s]

# %%
# Define the path to training data
train_path = "DATASET1/TRAIN"

# Visualization
from cv2 import cvtColor
import cv2
import glob
from tqdm import tqdm
import pandas as pd

x_data = []
y_data = []
for category in glob.glob(train_path + '/*'):
    for i, file in enumerate(tqdm(glob.glob(category + '/*'))):
        if i >= 10:  # Limit to 10 images per category for testing
            break
        img_array = cv2.imread(file)
        img_array = cv2.cvtColor(img_array, cv2.COLOR_BGR2RGB)
        x_data.append(img_array)
        y_data.append(category.split('/')[-1])

data = pd.DataFrame({'image': x_data, 'label': y_data})
# Out:
# ...
#   0%|          | 10/9999 [00:00<00:08, 1210.20it/s]

# %%
data.shape
# Out:
# (20, 2)

# %%
colors = ['#a0d157', '#c48bb8']
plt.pie(data.label.value_counts(), labels=['Organic', 'Recyclable'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[4], line 2
#       1 colors = ['#a0d157', '#c48bb8']
# ----> 2 plt.pie(data.label.value_counts(), labels=['Organic', 'Recyclable'])
#       3 plt.show()
#
# NameError: name 'plt' is not defined

# %%
import matplotlib.pyplot as plt  # Importing the pyplot module

colors = ['#a0d157', '#c48bb8']
plt.pie(data.label.value_counts(), labels=['Organic', 'Recyclable'], colors=colors, autopct='%0.2f%%', startangle = 90, explode=[0.05, 0.05])  # Added 'colors'
plt.show()
